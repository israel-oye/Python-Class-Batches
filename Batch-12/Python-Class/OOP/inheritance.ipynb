# %%
class Animal:
    def eat(self):
        print("Eating food...")


class Dog:
    def eat(self):
        print("Eating food...")


class Cat:
    def eat(self):
        print("Eating food...")
# Out:
# Eating food...
