# %%
for i in range(1, 6):
    for j in range(1, i+1):
        print(j, end='')
    print()
print()
for i in range(1, 6):
    for j in range(1, i+1):
        print(i, end='')
    print()
# Out:
# 1
# 12
# 123
# 1234
# 12345
#
# 1
# 22
# 333
# 4444
# 55555
