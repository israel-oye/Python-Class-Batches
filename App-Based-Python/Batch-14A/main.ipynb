# %%
print("Hello world")

# main_code
# module_1
# 1module ❌
# _my_var
# _0 ✅
print(4.112E4)

print(10_000)

# %%
# Strings
'abc'
'234'
'abc123'
')@(:E>)'
" "
"\n\t"

# %%
# Sequences

# lists
[3, 4, 5, 6]

names = ['Samuel', 'Tola', 'Ugochukwu']

names[2]

print(len(names))

# %%
# Tuples
pair = (4, 9)

pair[0]

len(pair)

data = (1, 'Ade', 'Male')
gender = data[2]
print(gender)

# %%
text = "abcd"

text[2]
len(text)

txt = "  "

print(len(txt))

# %%
list(range(1, 10, 2))

list(range(10))

range(4)[4]

# %%
# Range

list(range(10, 100, 10))

list(range(10))

list(range(1, 6))

# %%
# Mappings (Dictionary)
{
    "key": "Value",
    "another_key": "Another Value",
    "another_key_2": "Another Value",
}

data = {'classname': 'Python', 'student_count': 3}

data['student_count']

# %%
# Sets: an un-ordered collection of UNIQUE ITEMS
print({1, 2, 2, 1, 1, 1,  3, 3})

my_Set = {'Folu', 'Fola', 'Foya'}
my_Set

# %%
# Boolean
True
False

is_logged_in = True

# %%
# Variables

name = 'Seun'

print(name)

age = 44

the_thing_i_had_for_dinner_last_night = 'Amala'

# snake_case to name variables

y = 4
Y = 14

# %%
user_typed = input("Enter your name: ")

print(user_typed)

# %%
age = input("Enter your age: ")
age = int(age)
# print(type(age))

year_of_birth = 2026 - age

print(year_of_birth)
# Out:
# 1963

# %%
# Type conversion/type casting
str()
int()
float()
bool()
list()

# %%
str(45)

int('321')

float('-3.001')

int(50.999456)
# Out:
# 50

# %%
x = '1'
print(type(x))

x = int(x)

print(type(x))
# Out:
# <class 'str'>
# <class 'int'>

# %%
# Operators in Python


# Arithmetic Operators

# Addition

print(2 + 3)
print(4.5 + 2.34)

age = 16
age_next_year = age + 1
# Out:
# 5
# 6.84

# %%
# Subtraction

print(10 - 4)
print(3 - 20)
print(4.1 - (-2.4))

income = 2500
expenditure = 2900

bal = income - expenditure
print(bal)
# Out:
# 6
# -17
# 6.5
# -400

# %%
# Multiplication

print(4 * 3)

product_price = 56_549.99
units = 3

print(product_price * units)

print('ba' * 2)
print('-' * 10)
# Out:
# 12
# 169649.97
# baba
# ----------

# %%
# Division

print(40 / 2)

print(int(40 / 2))

money_to_share = 1000

print(money_to_share / 4)
# Out:
# 20.0
# 20
# 250.0

# %%
# Floor division

print((10 // 3), (10 / 3))

minutes = 124

hours = minutes // 60
print(hours)
# Out:
# 3 3.3333333333333335
# 2

# %%
# Modulo/Euclidean division

# 10 MOD 2 -> 5 r 0
# 3 mod 1 -> 3 R 0
# 17 MOD 6 -> 2 r 5

print(10 % 2)
print(3 % 1)
print(17 % 6)
# Out:
# 0
# 0
# 5

# %%
# Exponents/Power

print(2 ** 3)
print(4 ** 0.5)
print(49 ** 0.5)
# Out:
# 8
# 2.0
# 7.0

# %%
print(3 + 4 - 6 * 6 / 2)

print(3 + (4 - 6) * 6 / 2)


# Operator precedence: BEDMAS
# Out:
# -11.0
# -3.0

# %%
weight_kg = float(input("Enter weight (kg): "))

weight_g = weight_kg * 1000

print(weight_kg * 1000)
# Out:
# 24550.0

# %%
distance_km = float(input("Enter distance (km)"))

distance_m = distance_km * 1000

print(distance_m)
# Out:
# 2600.0

# %%
total_minutes_elapsed = 1027

hours = total_minutes_elapsed // 60
print(hours)

minutes = total_minutes_elapsed % 60
print(minutes)

print(f"{hours}:{minutes}")
# Out:
# 17
# 7
# 17:7

# %%
# Conctenation: add strings together

print('ab' + 'cd')

name = 'Shakir'

sentence = "My name is" + ' ' + name
print(sentence)

age = 19
sentence_1 = "I am " + str(age) + "years old"
print(sentence_1)


# F-strings: String Interpolation
print(f"I am {age} years old")

print(f"{0.123:.0f} is my expression")
# Out:
# abcd
# My name is Shakir
# I am 19years old
# I am 19 years old
# 0 is my expression

# %%
# Concatenation & F-strings

# %% [markdown]
# Assignment
#
# # 1. Celsius to Fahrenheit:
# # Ask the user for a temperature in Celsius and convert it to Fahrenheit.
# # - e.g Result: "30°C is equal to 86.0°F."
#
# # Formula
# # F = (9/5) * C + 32
#
# # 2. Miles to Kilometers:
# # Ask the user for a distance in miles and convert it to kilometers.
# # - e.g Result: "5 miles is equal to 8.0467 kilometers."
# # Formula
# # 1 mile = 1.609 km
#
# # 3. Calculate Perimeter:
# # Ask the user for the length and width of a rectangle, and calculate its perimeter.
# # - Result: "The perimeter is 30.0."

# %%
temp_c = float(input("Enter temperature (C): "))

temp_f = 1.8 * temp_c + 32

print(f"{temp_c}°C => {temp_f:.2f}°F")
# Out:
# 37.0°C => 98.60°F

# %%
# Assignment operators
# =
x = 6

x = x + 1
x += 10

y = 10
y -= 4 # y = y -4

z = 4
z *= 3

a = 30
a /= 5



print(y)

print(x)
# Out:
# 6
# 17

# %%
# Type-conversion 

print(bool('abc'))
print(bool(10))
print(bool(1.5))
print(bool([1, 2, 3]))
print(bool(('a', 'b')))
print(bool('0'))
print(bool(""))
print(bool(0.0))
print(bool([]))
print(bool(0.00001))
print(bool("  "))

# Truthy and Falsy values
# Out:
# True
# True
# True
# True
# True
# True
# False
# False
# False
# True
# True

# %%
# Comparison operators

# >, <, >=, <=, ==, !=

print(2 > 4)
print(4 < (10 - 5))
print(3 <= (6 / 2))
print(10.0 == 10)

print('5' != 5)
print('abc' == 'abc')
print('xyz'.upper() == 'XYZ')
print('abc' == ('a' + 'bc'))

words = """
jddjdj
jdjdjd
kdkdkdkd
"""

x = 70
f'''
this is a 
multiline
string {x}
'''

word = "line 1
line 2 
"
# Out:
# False
# True
# True
# True
# True
# True
# True
# True

# %%
'A' < 'z' # A-Za-z

# 'Z' < 'a'
# Out:
# True

# %%
# age = 17

# is_adult = (age >= 18)

# is_adult

height = float(input("Enter height (m): ")); is_tall = (height >= 1.9)

print(f"It is {is_tall} that you are tall")
# Out:
# It is True that you are tall
