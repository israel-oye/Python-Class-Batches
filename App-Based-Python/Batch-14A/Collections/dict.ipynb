# %%
# Dictionary

my_dict = {
    'name': "Ajoke Somefun",
    "age": 19,
    "gender": 'Female',
    'is_registered': False
}

number_names = {
    1: 'ONE',
    2: 'TWO',
    3: 'TROIS'
}

print(my_dict['name'].upper())
print(my_dict['age'] + 1)

# number_names[2]
# Out:
# AJOKE SOMEFUN
# 20
