# %%
f = open("note.txt")

f.read()
f.close()


# Context Managers
with open('note.txt') as f:
    # content = f.read()
    # print(len(content.split()))
    print(f.readlines())

print("outside block")
# Out:
# ['This is added from Python\n', 'Another line']
# outside block

# %%
with open('note.txt', 'w') as f:
    f.write("This is added from Python\n")
    f.write("Another line\n")

# %%
friends = ['Abu\n', 'Balow\n', 'Charlie\n']

with open('friends.txt', 'w') as f:
    f.writelines(friends)

# %%
with open('note.txt', 'r') as f:
    print(f.read())
    f.seek(1)
    print(f.read())
# Out:
# This is added from Python
# Another line
# his is added from Python
# Another line

# %%
with open('song.txt', 'w') as f:
    old_content = f.read()
    f.write(old_content + "\nI long to hold you again")

# %%
with open('song.txt', 'a') as f:
    f.write("\nI want to hold you again")

# %%
with open('new-file.txt', 'x') as f:
    pass
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 with open('new-file.txt', 'x') as f:
#       2     pass
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\interactiveshell.py:344, in _modified_open(file, *args, **kwargs)
#     337 if file in {0, 1, 2}:
#     338     raise ValueError(
#     339         f"IPython won't let you open fd={file} by default "
#     340         "as it is likely to crash IPython. If you know what you are doing, "
#     341         "you can use builtins' open."
#     342     )
# --> 344 return io_open(file, *args, **kwargs)
#
# FileExistsError: [Errno 17] File exists: 'new-file.txt'

# %%
with open('data.csv') as df:
    # print(df.readlines())
    total_ages = 0
    data_lines = df.readlines()[1:]
    for line in data_lines:
        print(line.split(','))
        name, age = line.split(',')
        age = int(age)
        total_ages += age

    print(total_ages / len(data_lines))
# Out:
# ['Ade', '10\n']
# ['Bolu', '11\n']
# ['Charles', '12\n']
# ['Doreen', '9']
# 10.5
