# %%
def foo():
    print("bar")

foo()
# Out:
# bar

# %%
# Function

def say_hello():
    print("Hello world")


# call a function
x = say_hello()

print(x)
# Out:
# Hello world
# None

# %%
def say_hello():
    return "Hello world"


# call a function
x = say_hello()

print(x)
# Out:
# Hello world

# %%
def greet_person(person):
    print(f"Hello {person}")

greet_person("Seun")
greet_person("Basit")
# Out:
# Hello Seun
# Hello Basit

# %%
def describe_pet(animal, name):
    print(f"I have a/an {animal} named {name}")

# Positional arguments
describe_pet('dog', 'Bingo')

describe_pet('kathryn', 'cat')

# Keyword arguments
describe_pet(name='Messi', animal='goat')


describe_pet('dog', name='Doug')
# Out:
# I have a/an dog named Bingo
# I have a/an kathryn named cat
# I have a/an goat named Messi

# %%
def func(x, y, z):
    print(x, y, z)


func(1, z=4, y=3)
func(10, 20, z=30)
func(30, y=20, x=1)
# Out:
# 1 3 4
# 10 20 30
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 7
#       5 func(1, z=4, y=3)
#       6 func(10, 20, z=30)
# ----> 7 func(30, y=20, x=1)
#
# TypeError: func() got multiple values for argument 'x'

# %% [markdown]
# Write a function called make_shirt() that accepts a size and the
# text of a message that should be printed on the shirt.
#
# The function should print
# a sentence summarizing the size of the shirt and the message printed on it.
#
# Call the function once using positional arguments to make a shirt. Call the
# function a second time using keyword arguments.

# %% [markdown]
# Write a function called city_country() that takes in the name
# of a city and its country.
#
# The function should return a string formatted like this:
# "Santiago, Chile"
#
# Call your function with at least three city-country pairs, and print the value that’s returned.

# %%
def city_country(city, country):
    return f"{city}, {country}"


print(city_country('Calabar', 'Nigeria'))

print(city_country(country='USA', city='New York'))
# Out:
# Calabar, Nigeria
# New York, USA

# %% [markdown]
# Album: Write a function called make_album() that builds a dictionary
# describing a music album. The function should take in an artist name and an
# album title, and it should return a dictionary containing these two pieces of
# information. Use the function to make three dictionaries representing different
# albums. Print each return value to show that the dictionaries are storing the
# album information correctly

# %%
def make_album(artist_name, album_title, tracks: int = 1):
    return {
        'artist': artist_name.title(),
        'album': album_title,
        'tracks': tracks
    }


album_1 = make_album("Chief Ebenezer Obey", "Evergreen Vol. 1")
album_2 = make_album("Paul Zach", "Field Recording, Vol. ")
album_3 = make_album(album_title='Hymns I', artist_name='LOVKN', tracks=14)

print(album_1, album_2, album_3, sep='\n')
# Out:
# {'artist': 'Chief Ebenezer Obey', 'album': 'Evergreen Vol. 1', 'tracks': 1}
# {'artist': 'Paul Zach', 'album': 'Field Recording, Vol. ', 'tracks': 1}
# {'artist': 'Lovkn', 'album': 'Hymns I', 'tracks': 14}

# %% [markdown]
# Add an optional parameter to make_album() that allows you to store the
# number of tracks on an album. If the calling line includes a value for the number of tracks, add that value to the album’s dictionary. Make at least one new
# function call that includes the number of tracks on an album.

# %%
def greet_person(person: str = ""):
    #docstring
    """ 
    This function salutes given `person` in English
    """
    print(f"Hello {person}")


greet_person()
greet_person(person='Akpan')
greet_person('Jude')
# Out:
# Hello
# Hello Akpan
# Hello Jude

# %%
x = 4 # Global scope

def foo():
    # Local Scope
    x = 40
    def bar():
        # Enclosing scope
        print(x)
    
    bar()
    print("Inside function", x)

print("Outside function", x)
foo()
# Out:
# Outside function 4
# 40
# Inside function 40

# %%
print(2, 3, 4, 5, 6, 7)
print(4, 5, 6)
print()

print(4, 8, sep='\t')
# Out:
# 2 3 4 5 6 7
# 4 5 6
#
# 4	8

# %%
pair = (3, 8)

pair_copy = [*pair]

pair_copy

# print(3, 8)
print(*pair)
# Out:
# 3 8

# %%
def adder(x: int, y: int):
    return x + y

print(adder(adder(5, 3), 2))

# ARBITRARY POSITIONAL ARGUMENTS
def add(*operands: int):
    return sum(operands)


add()
# Out:
# 10
# 0

# %% [markdown]
# Write a function that accepts a list of items a person wants
# on a sandwich. The function should have one parameter that collects as many
# items as the function call provides, and it should print a summary of the sandwich that is being ordered. Call the function three times, using a different number of arguments each time.

# %%
def sandwich_ingredients(*ingredients: str):
    print("---Sandwich Ingredients---")
    for i in ingredients:
        print(i)

sandwich_ingredients('ketchup', 'raisins', 'cheese')
# Out:
# ---Sandwich Ingredients---
# ketchup
# raisins
# cheese

# %%
def foo(**kwargs):
    print(kwargs)


foo(ham=4, bar='hey')
# Out:
# {'ham': 4, 'bar': 'hey'}

# %%
def build_profile(name: str, dob: str, **other_details):
    data = {
        'name': name,
        'date_of_birth': dob,
        **other_details
    }

    return data


build_profile("Lawal", "4/05/2026", sex="Male", weight=4.3)
build_profile(name="Kasali", dob="4/05/1996", occupation='Engineer', is_employed=True, friends=['Toyib', 'Hamza'])
# Out:
# {'name': 'Kasali',
#  'date_of_birth': '4/05/1996',
#  'occupation': 'Engineer',
#  'is_employed': True,
#  'friends': ['Toyib', 'Hamza']}

# %%
def func(param1, param2 = "", *args, **kwargs):
    print()

func()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 4
#       1 def func(param1, param2 = "", *args, **kwargs):
#       2     print()
# ----> 4 func()
#
# TypeError: func() missing 1 required positional argument: 'param1'

# %% [markdown]
# Write a function that stores information about a car in a dictionary. The function should always receive a manufacturer and a model name. It
# should then accept an arbitrary number of keyword arguments. Call the function with the required information and two other name-value pairs, such as a color or an optional feature. Your function should work for a call like this one:
# car = make_car('subaru', 'outback', color='blue', tow_package=True)
# Print the dictionary that’s returned to make sure all the information was
# stored correctly.

# %%
# Recursion: is a function/procedure that invokes itself

def factorial(n: int) -> int:
    '''Returns the factorial of given number, `n`'''
    if n == 1:
        return n
    return n * factorial(n - 1)

factorial(10)

x = 3
y = x

my_func = factorial
my_func(5)
# Functions as first-class citizens
# Out:
# 120

# %%
# Higher-Order Function: a function that takes one or more functions as an argument

def executor(f):
    f()

def foo():
    print("foo bar")

executor(f=foo)
# Out:
# foo bar

# %%
temperatures = [30, 10, 30.2]

def celsius_to_fahrenheit(temp: float):
    return temp * 1.8 + 32

# temps_in_fahrenheit = []
# for t in temperatures:
#     temps_in_fahrenheit.append(celsius_to_fahrenheit(t))

# print(temps_in_fahrenheit)

list(map(celsius_to_fahrenheit, temperatures))
list(map(lambda t: t * 1.8 + 32, temperatures))
# Out:
# [86.0, 50.0, 86.36]

# %%
change_case = lambda txt: txt.upper()

change_case('abc')

(lambda : print("hello"))() #IIFE: Immediately Invoked Function Expression
# Out:
# hello

# %%
my_list = [4, 7, 2, 9, 10, 3]
sorted_my_list = sorted(my_list)

print(sorted_my_list)
my_list.sort(reverse=True)

my_list

letters = list('hronwiksmb')
letters.sort(reverse=True)
letters
# Out:
# [2, 3, 4, 7, 9, 10]
# ['w', 's', 'r', 'o', 'n', 'm', 'k', 'i', 'h', 'b']

# %%
products = [
    {"id": 1, "name": "Laptop", "price": 1500.00, "color": 4281089616},
    {"id": 2, "name": "Smartphone", "price": 950.99, "color": 4281637083},
    {"id": 3, "name": "Tablet", "price": 599.99, "color": 4280193279},
    {"id": 4, "name": "Headphones", "price": 299.99, "color": 4293348412},
    {"id": 5, "name": "Smart Watch", "price": 399.99, "color": 4294928820},
]

def get_product_id(product: dict):
    return product['id']


get_product_id(product=products[0])
# sorted(products, key=get_product_id, reverse=True)
sorted(products, key=lambda p: p['name'])
# Out:
# [{'id': 4, 'name': 'Headphones', 'price': 299.99, 'color': 4293348412},
#  {'id': 1, 'name': 'Laptop', 'price': 1500.0, 'color': 4281089616},
#  {'id': 5, 'name': 'Smart Watch', 'price': 399.99, 'color': 4294928820},
#  {'id': 2, 'name': 'Smartphone', 'price': 950.99, 'color': 4281637083},
#  {'id': 3, 'name': 'Tablet', 'price': 599.99, 'color': 4280193279}]

# %%
prices_in_ngn = [1000, 200_000, 1_430_550, 10_500_000]

# Use a map function to transform the list above to a new list
# prices_in_usd

prices_in_usd = list(map(lambda p: round(p / 1350, 2), prices_in_ngn))

prices_in_usd
# Out:
# [0.74, 148.15, 1059.67, 7777.78]

# %%
names = ['Ada', 'Bryce', 'Chuks', 'Desmond', 'Ella']

def is_name_short(name: str):
    return len(name) <= 3

list(filter(is_name_short, names))
list(filter(lambda n: len(n) <= 3, names))
# Out:
# ['Ada']

# %%
products = [
    {"id": 1, "name": "Laptop", "price": 1500.00, "color": 4281089616},
    {"id": 2, "name": "Smartphone", "price": 950.99, "color": 4281637083},
    {"id": 3, "name": "Tablet", "price": 599.99, "color": 4280193279},
    {"id": 4, "name": "Headphones", "price": 299.99, "color": 4293348412},
    {"id": 5, "name": "Smart Watch", "price": 399.99, "color": 4294928820},
]

list(filter(lambda p: p['price'] <= 500, products))
# Out:
# [{'id': 4, 'name': 'Headphones', 'price': 299.99, 'color': 4293348412},
#  {'id': 5, 'name': 'Smart Watch', 'price': 399.99, 'color': 4294928820}]

# %%
from functools import reduce

numbers = range(4)

def add(x, y):
    return x + y

print(reduce(add, range(4)))

reduce(add, ('james', 'justin'))

reduce(lambda x, y: x + y['price'], products, 0)
# Out:
# 6
# 3750.959999999999

# %%
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '_1',
#  '_10',
#  '_11',
#  '_12',
#  '_13',
#  '_14',
#  '_15',
#  '_16',
#  '_18',
#  '_19',
#  '_2',
#  '_20',
#  '_21',
#  '_22',
#  '_23',
#  '_24',
#  '_25',
#  '_26',
#  '_27',
#  '_28',
#  '_29',
#  '_3',
#  '_30',
#  '_31',
#  '_33',
#  '_34',
#  '_35',
#  '_36',
#  '_37',
#  '_6',
#  '_7',
#  '_8',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '__vsc_ipynb_file__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i13',
#  '_i14',
#  '_i15',
#  '_i16',
#  '_i17',
#  '_i18',
#  '_i19',
#  '_i2',
#  '_i20',
#  '_i21',
#  '_i22',
#  '_i23',
#  '_i24',
#  '_i25',
#  '_i26',
#  '_i27',
#  '_i28',
#  '_i29',
#  '_i3',
#  '_i30',
#  '_i31',
#  '_i32',
#  '_i33',
#  '_i34',
#  '_i35',
#  '_i36',
#  '_i37',
#  '_i38',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'add',
# ...
