# %%
# Functions: stored procedure
# Built-in functions & User-defined functions

input() # calling  function
print()
len()
sum()
max()

# %%
# def function_name():
#   function body

age = int(input("Enter age": ))

if age <= 18:
    print("You're eligible to vote")
else:
    print("You can't vote")

# %%
username = input("Name: ")
print(f"Hello {username}")

# %% [markdown]
# Favorite Book: Write a function called favorite_book() that accepts one
# parameter, title. The function should print a message, such as "One of my favorite books is Alice in Wonderland".
# Call the function, making sure to include a book title as an argument in the function call.

# %%
# username = input("Name: ")
# print(f"Hello {username}")


def greet_person(name):
    print(f"Hello {name}")


greet_person("Oba")
greet_person("Akeem")
greet_person("Feyi")
greet_person(name="Dammy")

for name in ["Dele", "Elisa", "Fridolfo"]:
    greet_person(name)


def favorite_book(title):
    print(f"One of my favourite books is {title.title()}")


favorite_book("Things fall apart")
favorite_book(title="In Dependence")


def simple_func():
    print("This is a parameterless function")


# simple_func()

# %%
def describe_pet(animal_type, name):
    print(f"I have a/an {animal_type} named {name}")


# Positional arguments

describe_pet("dog", "Bullet")
describe_pet('Katrina', 'cat')
0
# Keyword arguments
describe_pet(name='Messi', animal_type='goat')

describe_pet('sheep', name='Sheeva')

# %% [markdown]
# T-Shirt: Write a function called make_shirt() that accepts a size and the text
# of a message that should be printed on the shirt.
#
# The function should print a sentence summarizing the size of the shirt and the message printed on it.
# Call the function once using positional arguments to make a shirt.
# Call the function a second time using keyword arguments.

# %%
def make_shirt(text, size='M',):
    print(f"This is a/an {size} shirt with {text} printed on top")

make_shirt('M', 'Fly Emirates')
make_shirt(size='XL', text='HARA')
make_shirt(text='iLovePDF')
# check_eligibility(19)
# You can vote

# %%
def check_eligibility(age):
    if age >= 18:
        print("You can vote")
    else:
        print("You CANNOT vote...")

check_eligibility(age=14)
check_eligibility(19)

# %%
# Default Parameters/Arguments
def say_hello(person="Anonymous"):
    print(f"Hello {person}")

# say_hello()
say_hello("Sam")

# %% [markdown]
# Write a function called describe_city() that accepts the name of
# a city and its country.
# The function should print a simple sentence, such as
# "Osogbo is in Nigeria."
# Give the parameter for the country a default value.
# Call your function for three different cities, at least one of which is not in the default country

# %%
def describe_city(city, country="Nigeria"):
    print(f"{city} is in {country}")

describe_city("Osogbo")

describe_city("Brussels", country='Belgium')

# %%
x = 2


def meter_to_km(meter):
    km = meter / 1000
    return km

def foo():
    print("br")

meter_to_km(2000)
meter_to_km(1500)
print("...")

# %%
x = 2


def meter_to_km(meter):
    km = meter / 1000
    return km


def foo():
    print("br")


m1 = meter_to_km(2000)
m2 = meter_to_km(1500)
print("...")
print(m1, m2)

# %%
x = 2


def meter_to_km(meter):
    km = meter / 1000
    print(km)


def returning_meter_to_km(meter):
    km = meter / 1000
    return km


m0 = meter_to_km(10_000)
print(m0)

m1 = returning_meter_to_km(500)
print(m1)

# %%
def square(number: int):
    return number ** 2

print(square(12))
print(square(5))

# Create a func: celsius_to_fahrenheit(temp)
# F = 1.8 x C + 32

def celsius_to_fahrenheit(temp: float):
    '''This converts a temperature in celsius to Fahrenheit'''
    f = 1.8 * temp + 32
    return
    print("After return")

celsius_to_fahrenheit(37)

# %%
def get_initials(firstname: str, surname: str):
    """This function returns the initials of a name""" #docstring
    initials = f"{firstname[0]}.{surname[0]}".upper()
    return initials

# get_initials("Bolu", "ajayi") #-> "B.A"
# get_initials("Vijay", "Najeem")
# get_initials(surname='Gboluwaga', firstname='Ilesanmi')
fname = input("Enter your firstname: ")
lname = input("Enter last name: ")

print(f"Yout initials are: {get_initials(fname, lname)}")

# %%
def analyze_nums(numbers: list):
    # TODO: assignment to include average in analysis
    
    analysis = {}
    even = []
    odd = []

    for n in numbers:
        if n % 2 == 0:
            even.append(n)
        else:
            odd.append(n)

    analysis['even'] = even
    analysis['odd'] = odd
    analysis['all'] = numbers

    return analysis
    


print(analyze_nums(numbers=[4, 11, 9, 17]))
print(analyze_nums([60, 22, 81, 99]))

# %%
def add(x, y):
    return x + y


print(add(add(4, 5), 2))

# Arbitrary arguments:
print()
print(1)
print(2, 3)
print(1, 2, 3, 4, 6, 7, 8, 9, 10)

# %%
def adder(*nums):
    total = 0
    for n in nums:
        total += n

    print(total)


# adder('aw', 'rt', 'tt')
adder(5, 6, 7, 8, 9, 10)
adder(1, 2)
adder(50, 60, 40, 55, 666, 77, 88, 99)

# %%
# Tuple unpacking

pair = (10, 20)

# print(10, 20)
print(pair)
print(*pair)
print(10, 20)

# %%
def describe_recipe(*ingredients, meal):
    print(f"Meal: {meal.title()}:\nIngredients:")

    for ingredient in ingredients:
        print(f"\t- {ingredient}")

describe_recipe('gari', 'water', 'salt', meal='Eba')

describe_recipe('rice', 'totmatoes', 'pepper', 'onions', 'seasoning', 'butter', meal='Jollof rice')

# %%
def describe_recipe(meal, *ingredients):
    print(f"Meal: {meal.title()}:\nIngredients:")

    for ingredient in ingredients:
        print(f"\t- {ingredient}")

describe_recipe("gari", "water", "salt", "Eba")
describe_recipe("boiled water")

# %% [markdown]
# Assignment
#
# *Exercise 1: Count the Items Passed*
#
# Create a function called `count_items()` that accepts any number of positional arguments and prints how many arguments were passed.
#
# *Example Output*
# `count_items("apple", "banana", "orange")`
#
# Output:
# `Total items: 3`
#
# *Requirements*
# - Use `*args`.
# - Print the number of arguments received.
# - Test the function with different numbers of arguments.
#
# —
#
# *Exercise 2: Find the Largest Number*
#
# Create a function called `find_largest()` that accepts any number of numbers and returns the largest one.
#
# *Example*
# `find_largest(10, 5, 30, 12)`
#
# Output:
# `30`
#
# *Requirements*
# - Use `*args`.
# - Do not hardcode the numbers.
# - Return the largest value.
#
# *Bonus Challenge*
# - Display a message if no numbers are supplied.
#
# —
#
# *Exercise 3: Classroom Statistics*
#
# Create a function called `class_statistics()` that accepts any number of student scores and displays:
# - The highest score
# - The lowest score
# - The average score
# - The total number of scores
#
# *Example*
# `class_statistics(75, 80, 92, 67, 88)`
#
# Output:
# `Highest Score: 92`
# `Lowest Score: 67`
# `Average Score: 80.4`
# `Total Scores: 5`

# %%
def class_statistics(*scores):
    print(f"Highest: {max(scores)}")
    print(f"Highest: {min(scores)}")
    print(f"Average: {sum(scores) / len(scores):.2f}")
    print(f"Total scores: {len(scores)}")


class_statistics(80, 85, 77, 91, 65)

# %%
# Arbitrary Keyword arguments

def func(name, country):
    print(name, country)


d = {'name': 'Seyi', 'country': "Benin"}

# func(name='Seyi', country='Benin')
func(**d)

# %%
def profile(name: str, **other_details):
    print(name, other_details)


profile('Godia', state='Plateau', lga='Jos North')
profile('Tanaka', country='Japan', dob='1970-01-01', age=57)

# %%
def product_details(**details):
    print("Product Information\n----------------------------------")
    for key, val in details.items():
        print(f"{key.title()}: {val}")

product_details(name='Laptop', price=2500, in_stock=True, qty=4)
print()
product_details(name='CeraVe', size=250, color='white')

# %% [markdown]
# Create a function called `report_card()` that accepts a student's subjects and their corresponding scores as keyword arguments. The function should print out
# - the average of the student's scores
# - the highest of their scores
# - the lowest of their scores
# - the number of subjects
#
# The output should look like the following example:
# ``` python
# report_card(English=71, Maths=81, Bio=95)
# # REPORT CARD
# # -------------
# # English: 71
# # Maths: 81
# # Bio: 95
#
# # Average: 42.3
# # Highest: 95
# # Lowest: 71
# # Subjects registered: 3
# ```

# %%
def report_card(**score_data):
    print("REPORT CARD\n----------")
    for course, score in score_data.items():
        print(f"{course.title()}: {score}")

    all_scores = score_data.values()
    registered_subjects_count = len(all_scores)

    print(f"\nRegistered subjects: {registered_subjects_count}")
    print(f"Highest score: {max(all_scores)}")
    print(f"Lowest score: {min(all_scores)}")
    print(f"Average score: {sum(all_scores) / len(all_scores)}")
    


report_card(English=71, Maths=81, Bio=95, Phy=90)
print()
report_card(civic=95, phe=87, cca=88, phonics=75)

# %%
def add(a, b=5, c=3):
    return a + b + c
    print("After returning...")


print(add(2, 10))

# %%
# Generators

def gen():
    yield 1
    yield 2
    yield 3

g = gen()
print(next(g))
print(next(g))
print(next(g))
print(next(g))

# %%
def with_return():
    return [1, 2, 3]


def with_yield():
    yield 1
    yield 2
    yield 3


# for i in with_return():
#     print(i)

val = with_return()

print("----\nGENERATOR:")

g = with_yield()
print(next(g))
print(next(g))
print(next(g))

# %%
def nums_creator(n: int):
    '''Creates aand returns a list from 0 to n'''
    return list(range(0, n + 1))

# nums_creator(10_000_000_000)

def nums_generator(n: int):
    i = 0
    while i < n + 1:
        yield i
        i += 1

# g = nums_generator(5)
# print(next(g))
# print(next(g))
# print(next(g))
# print(next(g))
# print(next(g))
# print(next(g))
# print(next(g))

for n in nums_generator(10_000_000_000):
    print(n)

# %%
def even_gen():
    i = 2
    while i <= 20:
        yield i
        i += 2


for n in even_gen():
    print(n)

# %%
def custom_range(start: int, stop: int, step: int):
    i = start

    while i < stop:
        yield i
        i += step

for i in custom_range(10, 20, 2):
    print(i)

# %%
# Higher Order Functions
# f(g(y))

def foo():
    print("foo...")

def greet(person: str):
    print(f"Hello {person}")

# First-class citizenship
my_func = foo
my_func()

greet_copy = greet
greet_copy('Keeb')

x = 2
y = x
print(y)

# %%
def say_hello():
    print("This function says hello")


func_var = say_hello

say_hello()
func_var()

# %%
# Map

def to_upper(string: str):
    '''This function returns the UPPPERCASE copy of a string'''
    return string.upper()


list(map(to_upper, ['Ada', 'Barbara', 'Chloe', 'Daphne']))


# def initil(fulln)
# list(map(initials, ['Kolawole Owode', 'Arambari Gumbau', 'Semilore Kupani']))
def doubler(n):
    return n * 2

doubled_nums = tuple(map(doubler, (60, 54, 33, 81)))
print(doubled_nums)

# %%
distances_covered_km = [5.5, 4.3, 5.6, 6.7, 6.8, 7.1, 3.2]

distance_covered_mi = []

for d_km in distances_covered_km:
    mi = d_km * 0.6213712
    distance_covered_mi.append(mi)

print(distance_covered_mi)

# %%
distances_covered_km = [5.5, 4.3, 5.6, 6.7, 6.8, 7.1, 3.2]

def km_to_mi(km: float):
    return km * 0.6213712

distance_covered_mi = list(map(km_to_mi, distances_covered_km))
print()

# %%
data = [
    (1, 'Akeem'),
    (2, 'Oyin'),
    (3, 'Bayo'),
    (4, 'Feyi'),
    (5, 'Oba')
]

def name_extractor(entry: tuple):
    return entry[1]

# name_extractor(entry=(10, 20, 30))
names = list(map(name_extractor, data))
print(names)

# %% [markdown]
# ## Assignment: Map Function Transformers
#
# Create three functions that work with Python's `map()` function:
#
# 1. **`celsius_to_fahrenheit(celsius)`** — Converts a single Celsius temperature to Fahrenheit using the formula: `(C × 9/5) + 32`
#
# 2. **`to_cube(number)`** — Returns the cube of a number
#
# 3. **`to_square(number)`** — Returns the square of a number
#
# Then demonstrate each with `map()`:
#
# ```python
# # Example usage (do not modify):
# temps = [0, 10, 20, 30, 100]
# numbers = [1, 2, 3, 4, 5]
#
# # Convert list of Celsius to Fahrenheit
# fahrenheit_temps = list(map(celsius_to_fahrenheit, temps))
# print(fahrenheit_temps)
#
# # Square each number
# squared = list(map(to_square, numbers))
# print(squared)
#
# # Cube each number
# cubed = list(map(to_cube, numbers))
# print(cubed)
# ```
#
# **Expected output:**
# ```
# [32.0, 50.0, 68.0, 86.0, 212.0]
# [1, 4, 9, 16, 25]
# [1, 8, 27, 64, 125]
# ```

# %%
def to_cube(n):
    return n ** 3

numbers = [1, 2, 3, 4, 5]

cubes = map(to_cube, numbers)
print(list(cubes))

# %%
# Filter: 
def is_even(n: int):
    # if n % 2 == 0:
    #     return True
    # else:
    #     return False
    return n % 2 == 0


numbers = range(1, 20)

list(filter(is_even, numbers))

# %%
if 2 > 1:
    print('True')
print('Outside if statement')

# %%
def a_checker(name: str):
    if name.title().startswith('A'):
        return True
    return False


names = ['Jude', 'James', 'Akeem', 'Roqeeb', 'Adedamola']

list(filter(a_checker, names))

# Use filter to create a list of all multiples of 15 from 0 to 1000
# Hint: use the range to get all numbers 0-1000

# %%
def is_multiple_of_15(n: int):
    return n % 15 == 0

list(filter(is_multiple_of_15, range(40, 1000)))

# %% [markdown]
# ## Higher-Order Functions Exercises: Filter and Reduce Challenges
#
# ### 1. Word Complexity Analyzer
# **Task:** Create a function that processes a list of words with the following requirements:
# - **Filter Criteria:**
#   1. Identify words longer than 4 characters
#   2. Find words containing at least one uppercase letter
# - **Reduction Challenge:**
#   - Calculate the total length of complex words (those with uppercase letters)
# - **Expected Output:**
#   - A dictionary with:
#     - List of long words
#     - List of complex words
#     - Total length of complex words
#
# **Input Example:**
# ```python
# words = ['apple', 'Banana', 'cat', 'Dolphin', 'elephant', 'Fox']
# ```

# %%
words = ["apple", "Banana", "cat", "Dolphin", "elephant", "Fox"]

'abBa'

def is_longer_than_4(word: str):
    return len(word) > 4
    # if len(word) > 4:
    #     return True
    # return False

def contains_uppercase_letter(word: str):
    for char in word:
        if char.isupper():
            return True

# def contains_letters(word: str, letter_1, letter_2):
#     return (letter_1 in word) and (letter_2 in word)

# contains_letters('President Trump', 'x', 't')
# list(filter(is_longer_than_4, words))

list(filter(contains_uppercase_letter, words))
# Out:
# ['Banana', 'Dolphin', 'Fox']

# %% [markdown]
# ### 2. Product Inventory Price Analysis
# **Task:** Develop a function to analyze a list of product dictionaries with these specifications:
# - **Filtering Requirements:**
#   1. Identify products priced above 50.0
# - **Reduction Challenges:**
#   1. Calculate total value of expensive products
#   2. Compute average price of expensive products
# - **Expected Output:**
#   - List of expensive products
#   - Total value of expensive products
#   - Average price of expensive products
#
# **Input Example:**
# ```python
# products = [
#     {'name': 'Laptop', 'price': 1200.0},
#     {'name': 'Mouse', 'price': 25.5},
#     {'name': 'Monitor', 'price': 300.0},
#     {'name': 'Keyboard', 'price': 80.0}
# ]
# ```

# %%
products = [
    {"name": "Laptop", "price": 1200.0},
    {"name": "Mouse", "price": 25.5},
    {"name": "Monitor", "price": 300.0},
    {"name": "Keyboard", "price": 80.0},
]

def price_is_above_50(product: dict):
    return product['price'] > 50

list(filter(price_is_above_50, products))
# Out:
# [{'name': 'Laptop', 'price': 1200.0},
#  {'name': 'Monitor', 'price': 300.0},
#  {'name': 'Keyboard', 'price': 80.0}]

# %%
# Reduce
from functools import reduce

def add(x, y):
    return x + y


scores = [46, 53, 40, 70, 81]

reduce(add, scores) - 20
# Out:
# 270

# %%
from functools import reduce

def concatenator(a: str, b: str):
    return a + b

words = ['Phone', 'Pad', 'Watch']

apple_names = reduce(concatenator, words, 'i')
print(apple_names)
# Out:
# iPhonePadWatch

# %%
incomes = [200, 450, 1500]

owing = -6000

def total(x, y):
    return x + y

bal = reduce(total, incomes, owing)
print(bal)
# Out:
# -3850

# %% [markdown]
# ### 1. Student Grade Performance Analyzer
# **Task:** Create a function to analyze student grade data with these requirements:
# - **Filtering Criteria:**
#   1. Identify students with grades above 85%
#   2. Find students who scored below the class average
# - **Reduction Challenges:**
#   1. Calculate total score for top-performing students
#   2. Compute the average score of high achievers
# - **Expected Output:**
#   - List of high-performing students
#   - Total score of top students
#   - Average score of top students
#
# **Input Example:**
# ```python
# students = [
#     {'name': 'Alice', 'grade': 92.5},
#     {'name': 'Bob', 'grade': 78.0},
#     {'name': 'Charlie', 'grade': 88.5},
#     {'name': 'David', 'grade': 65.0},
#     {'name': 'Eve', 'grade': 95.0}
# ]
# ```
# ### 2. Financial Transaction Analyzer
# **Task:** Design a function to process financial transactions with these specifications:
# - **Filtering Requirements:**
#   1. Separate income transactions (positive amounts)
#   2. Identify expense transactions (negative amounts)
#
# - **Reduction Challenges:**
#   1. Calculate total income
#   2. Calculate total expenses
#   3. Determine net financial balance
# - **Expected Output:**
#   - Count of income transactions
#   - Count of expense transactions
#   - Total income amount
#   - Total expenses amount
#   - Net financial balance
#
# **Input Example:**
# ```python
# transactions = [
#     {'description': 'Salary', 'amount': 5000.0},
#     {'description': 'Rent', 'amount': -1500.0},
#     {'description': 'Groceries', 'amount': -500.0},
#     {'description': 'Bonus', 'amount': 1000.0},
#     {'description': 'Utilities', 'amount': -300.0}
# ]
# ```
#
# ### 3. Fitness Activity Tracker
# **Task:** Develop a function to analyze fitness tracking data with these specifications:
# - **Filtering Requirements:**
#   1. Identify workout sessions longer than 45 minutes
#   2. Find high-intensity workouts (burning more than 400 calories)
# - **Reduction Challenges:**
#   1. Calculate total calories burned in high-intensity workouts
#   2. Compute average duration of long workouts
#
# - **Expected Output:**
#   - List of long workout sessions
#   - List of high-intensity workouts
#   - Total calories burned in high-intensity workouts
#   - Average duration of long workouts
#
# **Input Example:**
# ```python
# workouts = [
#     {'type': 'Running', 'duration': 30, 'calories': 350},
#     {'type': 'Cycling', 'duration': 60, 'calories': 500},
#     {'type': 'Swimming', 'duration': 45, 'calories': 400},
#     {'type': 'Weightlifting', 'duration': 40, 'calories': 250},
#     {'type': 'HIIT', 'duration': 50, 'calories': 450}
# ]
# ```

# %%
students = [
    {"name": "Alice", "grade": 92.5},
    {"name": "Bob", "grade": 78.0},
    {"name": "Charlie", "grade": 88.5},
    {"name": "David", "grade": 65.0},
    {"name": "Eve", "grade": 95.0},
]

def is_above_85(student: dict):
    return student['grade'] > 85

students_above_85 = list(filter(is_above_85, students))
print(students_above_85)
